# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/cars_en.csv')
print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (6675, 23)
#                                         ListingTitle  \
# 0  2016 AUDİ A3 SPORTBACK 1.0 TFSI BOYASIZ/DEĞİŞE...
# 1  2018 AUDİ A6 2.0 TDI QUATTRO SUNROOF MATRİX VA...
# 2       Sahibinden Audi A4 Sedan 1.8 TFSI 2011 Model
# 3  2016 AUDI A3 AMBİENTE *CAM TAVAN LED XENON HIZ...
# 4  Sahibinden Audi A3 Sportback 1.6 TDI S-Line 20...
#
#                      District            City    Price(TRY)  ListingID  \
# 0        Aşağısoku Mh. Merkez            Bolu  1.169.000 TL   27812680
# 1     Güneşevler Mh. Altındağ          Ankara  2.450.000 TL   28816234
# 2          Burmalı Mh. Merkez  Afyonkarahisar    750.000 TL   28781662
# 3          Ilıca Mh. Manavgat         Antalya  1.195.000 TL   28731117
# 4  Uğur Mumcu Mh. Yenimahalle          Ankara    822.000 TL   28393351
#
#      ListingDate Brand Series                            Model    Year  ...  \
# 0  07 April 2025  Audi     A3    A3 Sportback 1.0 TFSI Dynamic  2016.0  ...
# 1  07 April 2025  Audi     A6         A6 Sedan 2.0 TDI Quattro  2018.0  ...
# 2  08 April 2025  Audi     A4                A4 Sedan 1.8 TFSI  2011.0  ...
# 3  03 April 2025  Audi     A3    A3 Sportback 1.6 TDI Ambiente  2016.0  ...
# 4  02 April 2025  Audi     A3  A3 Sportback 1.6 TDI Attraction  2012.0  ...
#
#       BodyType  Color     EngineSize(cc) EnginePower(HP) DriveTrain  \
# 0  Hatchback/5  White  1200 cm3' e kadar    101 - 125 HP        FWD
# 1        Sedan  Black            1968 cc          190 hp        AWD
# 2        Sedan  White            1798 cc          160 hp        FWD
# 3  Hatchback/5  Black            1598 cc          110 hp        FWD
# 4  Hatchback/5  White            1598 cc          105 hp        FWD
#
#                               PaintAndPartsCondition       TradeInAvailable  \
# 0  Original  Right Rear Fender  Trunk Lid  Left R...      Trade-In Accepted
# 1  Original  Trunk Lid  Right Rear Door  Right Fr...  Trade-In Not Accepted
# 2  Original  Roof  Left Front Door  Hood  Front B...  Trade-In Not Accepted
# 3  Original  Right Rear Fender  Trunk Lid  Right ...      Trade-In Accepted
# 4  Original  Right Rear Fender  Trunk Lid  Left R...                    NaN
#
#        SellerType VehicleTax(TRY)       AccidentHistory
# 0             NaN             NaN                   NaN
# 1          Dealer             NaN  Amount not specified
# 2  Private Seller           2.013                75.000
# 3          Dealer           1.606        No tram amount
# 4             NaN             NaN  Amount not specified
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#                                            ListingTitle  \
# 6670  Sahibinden Opel Corsa 1.3 CDTI Enjoy 111 2010 ...
# 6671  ÇORUM MERKEZ 1999 HONDA CİVİC 1.4is TAVAN BOYASIZ
# 6672     Sahibinden Peugeot 206 1.4 X-Design 2005 Model
# 6673           Sahibinden Peugeot 206 1.6 XT 2001 Model
# 6674  Galeriden Renault Megane 1.5 dCi Touch Plus 20...
#
#                          District        City  Price(TRY)  ListingID  \
# 6670      Karapürçek Mh. Altındağ      Ankara  450.000 TL   29019564
# 6671           Ak Kent Mh. Merkez       Çorum  355.000 TL   29019753
# 6672    Cumhuriyet Mh. Lüleburgaz  Kırklareli  375.000 TL   29018858
# 6673      Batıkent Mh. Şehitkamil   Gaziantep  220.000 TL   29019438
# 6674  Yukarı Dudullu Mh. Ümraniye    İstanbul  770.000 TL   29022036
#
#         ListingDate    Brand  Series               Model    Year  ...  \
# 6670  16 April 2025     Opel   Corsa  1.3 CDTI Enjoy 111  2010.0  ...
# 6671  16 April 2025    Honda   Civic             1.4 i S  1999.0  ...
# 6672  16 April 2025  Peugeot     206        1.4 X-Design  2005.0  ...
# 6673  16 April 2025  Peugeot     206              1.6 XT  2001.0  ...
# 6674  16 April 2025  Renault  Megane  1.5 dCi Touch Plus  2017.0  ...
#
#          BodyType Color EngineSize(cc) EnginePower(HP) DriveTrain  \
# 6670  Hatchback/5   NaN        1248 cc           90 hp        FWD
# 6671        Sedan   NaN        1396 cc           90 hp        FWD
# 6672  Hatchback/3   NaN        1360 cc           76 hp        FWD
# 6673  Hatchback/5   NaN        1587 cc          109 hp        FWD
# 6674        Sedan   NaN        1461 cc          110 hp        FWD
#
#                                  PaintAndPartsCondition   TradeInAvailable  \
# 6670  Original  Right Rear Fender  Trunk Lid  Left R...                NaN
# 6671  Original  Roof  Locally Painted  -  Painted  R...  Trade-In Accepted
# 6672  Original  -  Locally Painted  -  Painted  Righ...                NaN
# 6673  Original  Right Rear Fender  Trunk Lid  Left R...                NaN
# 6674  Original  -  Locally Painted  -  Painted  -  R...  Trade-In Accepted
#
#           SellerType     VehicleTax(TRY)   AccidentHistory
# 6670  Private Seller                 NaN    No tram amount
# 6671             NaN  Yıllık MTV  436 TL    No tram amount
# 6672  Private Seller                 NaN  Tramer  3.000 TL
# 6673  Private Seller                 NaN               NaN
# 6674          Dealer                 NaN               NaN
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6675 entries, 0 to 6674
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ListingTitle            6675 non-null   object
#  1   District                6675 non-null   object
#  2   City                    6675 non-null   object
#  3   Price(TRY)              6675 non-null   object
#  4   ListingID               6675 non-null   int64
#  5   ListingDate             6675 non-null   object
#  6   Brand                   6675 non-null   object
#  7   Series                  6675 non-null   object
#  8   Model                   6674 non-null   object
#  9   Year                    6674 non-null   float64
#  10  Mileage(km)             6675 non-null   object
#  11  TransmissionType        6674 non-null   object
#  12  FuelType                6674 non-null   object
#  13  BodyType                6556 non-null   object
#  14  Color                   4220 non-null   object
#  15  EngineSize(cc)          6484 non-null   object
#  16  EnginePower(HP)         6477 non-null   object
#  17  DriveTrain              6438 non-null   object
#  18  PaintAndPartsCondition  6675 non-null   object
#  19  TradeInAvailable        2878 non-null   object
#  20  SellerType              3577 non-null   object
#  21  VehicleTax(TRY)         1961 non-null   object
#  22  AccidentHistory         3091 non-null   object
# dtypes: float64(1), int64(1), object(21)
# memory usage: 1.2+ MB

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
df[categorical_cols].nunique()
# Out:
# ListingTitle              5412
# District                  3170
# City                        81
# Price(TRY)                1376
# ListingDate                 62
# Brand                       39
# Series                     214
# Model                     1369
# Mileage(km)               1302
# TransmissionType             3
# FuelType                     5
# BodyType                     9
# Color                       23
# EngineSize(cc)             153
# EnginePower(HP)            163
# DriveTrain                   3
# PaintAndPartsCondition    2731
# TradeInAvailable             2
# SellerType                   4
# VehicleTax(TRY)             49
# AccidentHistory            601
# dtype: int64

# %%
df.isna().sum()
# Out:
# ListingTitle                 0
# District                     0
# City                         0
# Price(TRY)                   0
# ListingID                    0
# ListingDate                  0
# Brand                        0
# Series                       0
# Model                        1
# Year                         1
# Mileage(km)                  0
# TransmissionType             1
# FuelType                     1
# BodyType                   119
# Color                     2455
# EngineSize(cc)             191
# EnginePower(HP)            198
# DriveTrain                 237
# PaintAndPartsCondition       0
# TradeInAvailable          3797
# SellerType                3098
# VehicleTax(TRY)           4714
# AccidentHistory           3584
# dtype: int64

# %% [markdown]
# ## Target Selection + Cleaning
#
# ### Brand

# %%
# Define target and predictors
target = 'Brand'
predictors = [col for col in df.columns if col != target]

print(f"Target variable: {target}")
print(f"Number of predictors: {len(predictors)}")
print(f"Predictors: {predictors}")
# Out:
# Target variable: Brand
# Number of predictors: 22
# Predictors: ['ListingTitle', 'District', 'City', 'Price(TRY)', 'ListingID', 'ListingDate', 'Series', 'Model', 'Year', 'Mileage(km)', 'TransmissionType', 'FuelType', 'BodyType', 'Color', 'EngineSize(cc)', 'EnginePower(HP)', 'DriveTrain', 'PaintAndPartsCondition', 'TradeInAvailable', 'SellerType', 'VehicleTax(TRY)', 'AccidentHistory']

# %%
import matplotlib.pyplot as plt

# Bar plot of target distribution
plt.figure(figsize=(14, 8))
brand_counts = df['Brand'].value_counts()

plt.bar(brand_counts.index, brand_counts.values, color='steelblue', alpha=0.7)
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Distribution of Car Brands (Target Variable)', fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

print(f"Total unique brands: {df['Brand'].nunique()}")
print(f"Top 10 brands:")
print(brand_counts.head(10))
# Out:
# Total unique brands: 39
# Top 10 brands:
# Brand
# Renault       1077
# Volkswagen     809
# Fiat           712
# Opel           673
# BMW            557
# Peugeot        537
# Toyota         536
# Ford           528
# Audi           495
# Hyundai        494
# Name: count, dtype: int64

# %%
# Filter dataset to keep only top brands for classification
top_brands = brand_counts.head(10).index.tolist()

# Filter the dataset
df_filtered = df[df['Brand'].isin(top_brands)].copy()

print(f"\nOriginal dataset shape: {df.shape}")
print(f"Filtered dataset shape: {df_filtered.shape}")
print(f"Percentage of data retained: {(len(df_filtered)/len(df))*100:.1f}%")
# Out:
# Original dataset shape: (6675, 23)
# Filtered dataset shape: (6418, 23)
# Percentage of data retained: 96.1%

# %%
# Visualize filtered target distribution
plt.figure(figsize=(12, 6))
plt.bar(filtered_brand_counts.index, filtered_brand_counts.values, color='steelblue', alpha=0.7)
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Filtered Dataset - Top 10 Car Brands Distribution', fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Predictor Selection + Cleaning

# %%
df.columns
# Out:
# Index(['ListingTitle', 'District', 'City', 'Price(TRY)', 'ListingID',
#        'ListingDate', 'Brand', 'Series', 'Model', 'Year', 'Mileage(km)',
#        'TransmissionType', 'FuelType', 'BodyType', 'Color', 'EngineSize(cc)',
#        'EnginePower(HP)', 'DriveTrain', 'PaintAndPartsCondition',
#        'TradeInAvailable', 'SellerType', 'VehicleTax(TRY)', 'AccidentHistory'],
#       dtype='object')

# %%
df = df.drop(columns=["ListingTitle", "District", 
    "ListingID", "Color", "PaintAndPartsCondition", 
    "TradeInAvailable", "SellerType", "VehicleTax(TRY)",
    "AccidentHistory"], errors="ignore")

# %%
df.isna().sum()
# Out:
# City                  0
# Price(TRY)            0
# ListingDate           0
# Brand                 0
# Series                0
# Model                 1
# Year                  1
# Mileage(km)           0
# TransmissionType      1
# FuelType              1
# BodyType            119
# EngineSize(cc)      191
# EnginePower(HP)     198
# DriveTrain          237
# dtype: int64

# %%
# Data cleaning 
df['Price(TRY)'] = df['Price(TRY)'].str.replace('TL', '', regex=False)  
df['Price(TRY)'] = df['Price(TRY)'].str.replace('.', '', regex=False)   
df['Price(TRY)'] = df['Price(TRY)'].str.strip()                         
df['Price(TRY)'] = df['Price(TRY)'].astype(int) 

df = df[df['Mileage(km)'].str.replace('.', '', regex=False)
                   .str.replace('km', '', regex=False)
                   .str.strip()
                   .str.isnumeric()]

df['Mileage(km)'] = df['Mileage(km)'].str.replace('km', '', regex=False)
df['Mileage(km)'] = df['Mileage(km)'].str.replace('.', '', regex=False)
df['Mileage(km)'] = df['Mileage(km)'].str.strip()
df['Mileage(km)'] = df['Mileage(km)'].astype(int)

df['EngineSize(cc)'] = df['EngineSize(cc)'].str.extract(r'(\d+)')   
df['EngineSize(cc)'] = pd.to_numeric(df['EngineSize(cc)'], errors='coerce')  
df['EngineSize(cc)'] = df['EngineSize(cc)'].astype('Int64')  

df['EnginePower(HP)'] = df['EnginePower(HP)'].str.extract(r'(\d+)')   
df['EnginePower(HP)'] = pd.to_numeric(df['EnginePower(HP)'], errors='coerce')  
df['EnginePower(HP)'] = df['EnginePower(HP)'].astype('Int64') 

df['ListingDate'] = pd.to_datetime(df['ListingDate'], format='%d %B %Y')
df['ListingYear'] = df['ListingDate'].dt.year
df['ListingMonth'] = df['ListingDate'].dt.month
df['ListingDay'] = df['ListingDate'].dt.day
df = df.drop('ListingDate', axis=1)

df['Year'] = df['Year'].astype(int)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6674 entries, 0 to 6674
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              6674 non-null   object
#  1   Price(TRY)        6674 non-null   int64
#  2   Brand             6674 non-null   object
#  3   Series            6674 non-null   object
#  4   Model             6673 non-null   object
#  5   Year              6674 non-null   int64
#  6   Mileage(km)       6674 non-null   int64
#  7   TransmissionType  6674 non-null   object
#  8   FuelType          6673 non-null   object
#  9   BodyType          6555 non-null   object
#  10  EngineSize(cc)    6484 non-null   Int64
#  11  EnginePower(HP)   6476 non-null   Int64
#  12  DriveTrain        6438 non-null   object
#  13  ListingYear       6674 non-null   int32
#  14  ListingMonth      6674 non-null   int32
#  15  ListingDay        6674 non-null   int32
# dtypes: Int64(2), int32(3), int64(3), object(8)
# memory usage: 821.2+ KB

# %%
# Labelling (do not encode target variable 'Brand')
from sklearn.preprocessing import LabelEncoder

categoric_cols = [col for col in df.select_dtypes(include=['object', 'category']).columns if col != 'Brand']
le = LabelEncoder()
for col in categoric_cols:
    df[col] = le.fit_transform(df[col].astype(str))

df.head()
# Out:
#    City  Price(TRY) ListingDate  Brand  Series  Model  Year  Mileage(km)  \
# 0    18     1169000  2025-04-07      2      34   1196  2016       120000
# 1     5     2450000  2025-04-07      2      37   1271  2018       136000
# 2     2      750000  2025-04-08      2      35   1239  2011       285000
# 3     6     1195000  2025-04-03      2      34   1210  2016       101000
# 4     5      822000  2025-04-02      2      34   1212  2012       212000
#
#    TransmissionType  FuelType  BodyType  EngineSize(cc)  EnginePower(HP)  \
# 0                 0         2         3            1200              101
# 1                 2         0         7            1968              190
# 2                 0         2         7            1798              160
# 3                 2         0         3            1598              110
# 4                 2         0         3            1598              105
#
#    DriveTrain
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1
